# %% [markdown]
# ### Title:
# # Exploratory Data Analysis

# %% [markdown]
# ### Description:
# We are going to perform an EDA of our dataset.

# %% [markdown]
# ### Authors:
# #### Hugo Cesar Octavio del Sueldo
# #### Jose Lopez Galdon

# %% [markdown]
# ### Date:
# 04/11/2020

# %% [markdown]
# ### Version:
# 1.0

# %% [markdown]
# ***

# %% [markdown]
# ### Libraries

# %% [markdown]
# We are going to start this EDA loading the respective libraries

# %%
    # Numpy & Pandas to work with the DF
import numpy as np
import pandas as pd

    # Seaborn / matplotlib for graphs
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

    # Pre-processing
from sklearn import preprocessing,metrics 
    
    # Random samples
from random import sample

    # Visualize DF
from IPython.display import display, HTML

    # Import Sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV

    # Authomatic reports
import sweetviz as sv

# %% [markdown]
# ***

# %% [markdown]
# ## Load data

# %%
    # To automate the work as much as possible, we will parameterize the codes, so in this case, we will create an objetct with
    # the path root
name = 'data_train_merge'

data = pd.read_csv(f'../data/02_intermediate/{name}.csv',  # Path root: here we include an f-string with the variable name
                   low_memory = False)                     # To avoid warnings we use set low_memory = False

# %% [markdown]
# ***

# %% [markdown]
# ## Variable predict

# %% [markdown]
# Taking into account the goals of the practice, we only want to know those persons that `Fully paid` their loans or those who does not, so we will tansform the dependent variable into binary problem, to ones or ceros depending on that condition.
#
# So we are going to predict the variable `loan_status` which are classified in different sections:
#
# - **Current**: Loan is up to date on all outstanding payments.
#
# - **In Grace Period**: Loan is past due but within the 15-day grace period.
#
# - **Late (16-30)**: Loan has not been current for 16 to 30 days.
#
# - **Late (31-120)**: Loan has not been current for 31 to 120 days.
#
# - **Fully paid**: Loan has been fully repaid, either at the expiration of the 3- or 5-year year term or as a result of a prepayment.
#
# - **Default**: Loan has not been current for an extended period of time.
#
# - **Charged Off***: Loan for which there is no longer a reasonable expectation of further payments. Upon Charge Off, the remaining principal balance of the Note is deducted from the account balance.
#
# As we know, our problem is to predict who is going to pay or not. Due to this we will select **Fully paid**, **Default** and **Charged Off**. **default** and **Charged Off** will be treated as the same variable, because they almost explain the same condition:
#
# *Loans that are in "Default" are loans for which borrowers have failed to make payments for an extended period of time.*
#
# *A loan becomes “Charged Off” when there is no longer a reasonable expectation of further payments.  Charge Off typically occurs when a loan is 120 days or more past due and there is no reasonable expectation of sufficient payment to prevent the charge off.  In certain circumstances, loans may be charged off at an earlier or later date.  Please note, loans for which borrowers have filed for bankruptcy may be charged off earlier based on the date of bankruptcy notification.*
#
# *A loan that is in “Default” will still appear in your Notes, in the status of “Default,” while a loan that has been “Charged Off” will appear as charged off, and the remaining principal balance of the Note will be deducted from your account balance.*

# %%
    # First we create a dataset with the loan_status variables
loan = data['loan_status'].value_counts()
loan = loan.to_frame()
loan.reset_index(inplace = True)

    # We set the name columns
loan.columns = ['Loan Status', 'Count']

    # Set the heigth and width size
plt.subplots(figsize = (15, 7))

    # Plot with seaborn
sns.barplot(y='Count', x='Loan Status', data = loan, palette = 'rocket_r');

    # Labels
plt.xlabel("Loan statuses");
plt.ylabel("Frequency");
plt.title("Distribution of Loan Status in our Dataset");

# %% [markdown]
# As you can see, we have a lot of loans which are current with fair amount of fully paid loans. Other categories (including) default have a really low number. This could mean that the data is imbalanced and we might need to do something about this later in the analysis. Therefore, we will merge **Charged Off** and **Default**, this will be our *non-payment* variable.

# %%
    # Merge Default & Charged Off
data['loan_status'] = data['loan_status'].replace({'Default':'Charged Off'})

    # We will only select those observations with "Fully Paid" & "Charged Off"
data_binary = data[(data['loan_status'] == "Fully Paid") | (data['loan_status'] == "Charged Off")]

    # Now, we will transform into 0 & 1
dummy_dict = {"Fully Paid":0, "Charged Off":1}

    # Finally, we use the dictiony in the dataset
data = data_binary.replace({"loan_status": dummy_dict})

# %% [markdown]
# We will perform the same graph...

# %%
    # First we create a dataset with the loan_status variables
loan = data['loan_status'].value_counts()
loan = loan.to_frame()
loan.reset_index(inplace = True)

    # We set the name columns
loan.columns = ['Loan Status', 'Count']

    # Set the heigth and width size
plt.subplots(figsize = (15, 7))

    # Plot with seaborn
sns.barplot(y='Count', x='Loan Status', data = loan, palette = 'rocket_r');

    # Labels
plt.xlabel("Loan statuses");
plt.ylabel("Frequency");
plt.title("Distribution of Loan Status in our Dataset");

# %% [markdown]
# As we said before we may have an imbalanced dataset, if we run the algorithms with this proportion it will bias to the ceros(payment), so if we recieve a new client will have more probability to be a cero than a one, and that could lead us to the wrong decission.

# %% [markdown]
# ### View data

# %% [markdown]
# Firstly, we are goint to take a look to our dataframe:

# %%
    # First 5 rows using html display in order to view all the columns
data = data
display(HTML(data.head().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>member_id</th>
#       <th>loan_amnt</th>
#       <th>funded_amnt</th>
#       <th>funded_amnt_inv</th>
#       <th>term</th>
#       <th>int_rate</th>
#       <th>installment</th>
#       <th>grade</th>
#       <th>sub_grade</th>
#       <th>emp_title</th>
#       <th>emp_length</th>
#       <th>home_ownership</th>
#       <th>annual_inc</th>
#       <th>verification_status</th>
#       <th>issue_d</th>
#       <th>loan_status</th>
#       <th>pymnt_plan</th>
#       <th>url</th>
#       <th>desc</th>
#       <th>purpose</th>
#       <th>title</th>
#       <th>zip_code</th>
#       <th>addr_state</th>
#       <th>dti</th>
#       <th>delinq_2yrs</th>
#       <th>earliest_cr_line</th>
#       <th>fico_range_low</th>
#       <th>fico_range_high</th>
#       <th>inq_last_6mths</th>
#       <th>mths_since_last_delinq</th>
#       <th>mths_since_last_record</th>
#       <th>open_acc</th>
#       <th>pub_rec</th>
#       <th>revol_bal</th>
#       <th>revol_util</th>
#       <th>total_acc</th>
#       <th>initial_list_status</th>
#       <th>out_prncp</th>
#       <th>out_prncp_inv</th>
#       <th>total_pymnt</th>
#       <th>total_pymnt_inv</th>
#       <th>total_rec_prncp</th>
#       <th>total_rec_int</th>
#       <th>total_rec_late_fee</th>
#       <th>recoveries</th>
#       <th>collection_recovery_fee</th>
#       <th>last_pymnt_d</th>
#       <th>last_pymnt_amnt</th>
#       <th>next_pymnt_d</th>
#       <th>last_credit_pull_d</th>
#       <th>last_fico_range_high</th>
#       <th>last_fico_range_low</th>
#       <th>collections_12_mths_ex_med</th>
#       <th>mths_since_last_major_derog</th>
#       <th>policy_code</th>
#       <th>application_type</th>
#       <th>annual_inc_joint</th>
#       <th>dti_joint</th>
#       <th>verification_status_joint</th>
#       <th>acc_now_delinq</th>
#       <th>tot_coll_amt</th>
#       <th>tot_cur_bal</th>
#       <th>open_acc_6m</th>
#       <th>open_act_il</th>
#       <th>open_il_12m</th>
#       <th>open_il_24m</th>
#       <th>mths_since_rcnt_il</th>
#       <th>total_bal_il</th>
#       <th>il_util</th>
#       <th>open_rv_12m</th>
#       <th>open_rv_24m</th>
#       <th>max_bal_bc</th>
#       <th>all_util</th>
#       <th>total_rev_hi_lim</th>
#       <th>inq_fi</th>
#       <th>total_cu_tl</th>
#       <th>inq_last_12m</th>
#       <th>acc_open_past_24mths</th>
#       <th>avg_cur_bal</th>
#       <th>bc_open_to_buy</th>
#       <th>bc_util</th>
#       <th>chargeoff_within_12_mths</th>
#       <th>delinq_amnt</th>
#       <th>mo_sin_old_il_acct</th>
#       <th>mo_sin_old_rev_tl_op</th>
#       <th>mo_sin_rcnt_rev_tl_op</th>
#       <th>mo_sin_rcnt_tl</th>
#       <th>mort_acc</th>
#       <th>mths_since_recent_bc</th>
#       <th>mths_since_recent_bc_dlq</th>
#       <th>mths_since_recent_inq</th>
#       <th>mths_since_recent_revol_delinq</th>
#       <th>num_accts_ever_120_pd</th>
#       <th>num_actv_bc_tl</th>
#       <th>num_actv_rev_tl</th>
#       <th>num_bc_sats</th>
#       <th>num_bc_tl</th>
#       <th>num_il_tl</th>
#       <th>num_op_rev_tl</th>
#       <th>num_rev_accts</th>
#       <th>num_rev_tl_bal_gt_0</th>
#       <th>num_sats</th>
#       <th>num_tl_120dpd_2m</th>
#       <th>num_tl_30dpd</th>
#       <th>num_tl_90g_dpd_24m</th>
#       <th>num_tl_op_past_12m</th>
#       <th>pct_tl_nvr_dlq</th>
#       <th>percent_bc_gt_75</th>
#       <th>pub_rec_bankruptcies</th>
#       <th>tax_liens</th>
#       <th>tot_hi_cred_lim</th>
#       <th>total_bal_ex_mort</th>
#       <th>total_bc_limit</th>
#       <th>total_il_high_credit_limit</th>
#       <th>revol_bal_joint</th>
#       <th>sec_app_fico_range_low</th>
#       <th>sec_app_fico_range_high</th>
#       <th>sec_app_earliest_cr_line</th>
#       <th>sec_app_inq_last_6mths</th>
#       <th>sec_app_mort_acc</th>
#       <th>sec_app_open_acc</th>
#       <th>sec_app_revol_util</th>
#       <th>sec_app_open_act_il</th>
#       <th>sec_app_num_rev_accts</th>
#       <th>sec_app_chargeoff_within_12_mths</th>
#       <th>sec_app_collections_12_mths_ex_med</th>
#       <th>sec_app_mths_since_last_major_derog</th>
#       <th>hardship_flag</th>
#       <th>hardship_type</th>
#       <th>hardship_reason</th>
#       <th>hardship_status</th>
#       <th>deferral_term</th>
#       <th>hardship_amount</th>
#       <th>hardship_start_date</th>
#       <th>hardship_end_date</th>
#       <th>payment_plan_start_date</th>
#       <th>hardship_length</th>
#       <th>hardship_dpd</th>
#       <th>hardship_loan_status</th>
#       <th>orig_projected_additional_accrued_interest</th>
#       <th>hardship_payoff_balance_amount</th>
#       <th>hardship_last_payment_amount</th>
#       <th>disbursement_method</th>
#       <th>debt_settlement_flag</th>
#       <th>debt_settlement_flag_date</th>
#       <th>settlement_status</th>
#       <th>settlement_date</th>
#       <th>settlement_amount</th>
#       <th>settlement_percentage</th>
#       <th>settlement_term</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8</th>
#       <td>112038251</td>
#       <td>NaN</td>
#       <td>11575</td>
#       <td>11575</td>
#       <td>11575.0</td>
#       <td>36 months</td>
#       <td>7.35%</td>
#       <td>359.26</td>
#       <td>A</td>
#       <td>A4</td>
#       <td>Solutions Architect</td>
#       <td>6 years</td>
#       <td>OWN</td>
#       <td>153000.0</td>
#       <td>Not Verified</td>
#       <td>Jun-2017</td>
#       <td>0</td>
#       <td>n</td>
#       <td>https://lendingclub.com/browse/loanDetail.action?loan_id=112038251</td>
#       <td>NaN</td>
#       <td>credit_card</td>
#       <td>Credit card refinancing</td>
#       <td>923xx</td>
#       <td>CA</td>
#       <td>16.99</td>
#       <td>0</td>
#       <td>Jul-1994</td>
#       <td>720</td>
#       <td>724</td>
#       <td>0</td>
#       <td>24.0</td>
#       <td>84.0</td>
#       <td>20</td>
#       <td>1</td>
#       <td>8550</td>
#       <td>22.7%</td>
#       <td>46</td>
#       <td>w</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>11707.816236</td>
#       <td>11707.82</td>
#       <td>11575.0</td>
#       <td>132.82</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>Sep-2017</td>
#       <td>11360.38</td>
#       <td>NaN</td>
#       <td>Sep-2017</td>
#       <td>724</td>
#       <td>720</td>
#       <td>0</td>
#       <td>24.0</td>
#       <td>1</td>
#       <td>Individual</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>0</td>
#       <td>442731</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>27.0</td>
#       <td>92315.0</td>
#       <td>63.0</td>
#       <td>2.0</td>
#       <td>8.0</td>
#       <td>1581.0</td>
#       <td>36.0</td>
#       <td>37600</td>
#       <td>1.0</td>
#       <td>6.0</td>
#       <td>2.0</td>
#       <td>8</td>
#       <td>23302.0</td>
#       <td>24269.0</td>
#       <td>13.6</td>
#       <td>0</td>
#       <td>0</td>
#       <td>130.0</td>
#       <td>275</td>
#       <td>3</td>
#       <td>3</td>
#       <td>2</td>
#       <td>3.0</td>
#       <td>NaN</td>
#       <td>7.0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>6</td>
#       <td>9</td>
#       <td>9</td>
#       <td>16</td>
#       <td>12</td>
#       <td>16</td>
#       <td>32.0</td>
#       <td>9</td>
#       <td>20</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>95.7</td>
#       <td>11.1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>528172</td>
#       <td>100865</td>
#       <td>28100</td>
#       <td>120572</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>N</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Cash</td>
#       <td>N</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>112149045</td>
#       <td>NaN</td>
#       <td>7200</td>

# %%
    # Last 5 rows using html display in order to view all the columns
data = data
display(HTML(data.tail().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>member_id</th>
#       <th>loan_amnt</th>
#       <th>funded_amnt</th>
#       <th>funded_amnt_inv</th>
#       <th>term</th>
#       <th>int_rate</th>
#       <th>installment</th>
#       <th>grade</th>
#       <th>sub_grade</th>
#       <th>emp_title</th>
#       <th>emp_length</th>
#       <th>home_ownership</th>
#       <th>annual_inc</th>
#       <th>verification_status</th>
#       <th>issue_d</th>
#       <th>loan_status</th>
#       <th>pymnt_plan</th>
#       <th>url</th>
#       <th>desc</th>
#       <th>purpose</th>
#       <th>title</th>
#       <th>zip_code</th>
#       <th>addr_state</th>
#       <th>dti</th>
#       <th>delinq_2yrs</th>
#       <th>earliest_cr_line</th>
#       <th>fico_range_low</th>
#       <th>fico_range_high</th>
#       <th>inq_last_6mths</th>
#       <th>mths_since_last_delinq</th>
#       <th>mths_since_last_record</th>
#       <th>open_acc</th>
#       <th>pub_rec</th>
#       <th>revol_bal</th>
#       <th>revol_util</th>
#       <th>total_acc</th>
#       <th>initial_list_status</th>
#       <th>out_prncp</th>
#       <th>out_prncp_inv</th>
#       <th>total_pymnt</th>
#       <th>total_pymnt_inv</th>
#       <th>total_rec_prncp</th>
#       <th>total_rec_int</th>
#       <th>total_rec_late_fee</th>
#       <th>recoveries</th>
#       <th>collection_recovery_fee</th>
#       <th>last_pymnt_d</th>
#       <th>last_pymnt_amnt</th>
#       <th>next_pymnt_d</th>
#       <th>last_credit_pull_d</th>
#       <th>last_fico_range_high</th>
#       <th>last_fico_range_low</th>
#       <th>collections_12_mths_ex_med</th>
#       <th>mths_since_last_major_derog</th>
#       <th>policy_code</th>
#       <th>application_type</th>
#       <th>annual_inc_joint</th>
#       <th>dti_joint</th>
#       <th>verification_status_joint</th>
#       <th>acc_now_delinq</th>
#       <th>tot_coll_amt</th>
#       <th>tot_cur_bal</th>
#       <th>open_acc_6m</th>
#       <th>open_act_il</th>
#       <th>open_il_12m</th>
#       <th>open_il_24m</th>
#       <th>mths_since_rcnt_il</th>
#       <th>total_bal_il</th>
#       <th>il_util</th>
#       <th>open_rv_12m</th>
#       <th>open_rv_24m</th>
#       <th>max_bal_bc</th>
#       <th>all_util</th>
#       <th>total_rev_hi_lim</th>
#       <th>inq_fi</th>
#       <th>total_cu_tl</th>
#       <th>inq_last_12m</th>
#       <th>acc_open_past_24mths</th>
#       <th>avg_cur_bal</th>
#       <th>bc_open_to_buy</th>
#       <th>bc_util</th>
#       <th>chargeoff_within_12_mths</th>
#       <th>delinq_amnt</th>
#       <th>mo_sin_old_il_acct</th>
#       <th>mo_sin_old_rev_tl_op</th>
#       <th>mo_sin_rcnt_rev_tl_op</th>
#       <th>mo_sin_rcnt_tl</th>
#       <th>mort_acc</th>
#       <th>mths_since_recent_bc</th>
#       <th>mths_since_recent_bc_dlq</th>
#       <th>mths_since_recent_inq</th>
#       <th>mths_since_recent_revol_delinq</th>
#       <th>num_accts_ever_120_pd</th>
#       <th>num_actv_bc_tl</th>
#       <th>num_actv_rev_tl</th>
#       <th>num_bc_sats</th>
#       <th>num_bc_tl</th>
#       <th>num_il_tl</th>
#       <th>num_op_rev_tl</th>
#       <th>num_rev_accts</th>
#       <th>num_rev_tl_bal_gt_0</th>
#       <th>num_sats</th>
#       <th>num_tl_120dpd_2m</th>
#       <th>num_tl_30dpd</th>
#       <th>num_tl_90g_dpd_24m</th>
#       <th>num_tl_op_past_12m</th>
#       <th>pct_tl_nvr_dlq</th>
#       <th>percent_bc_gt_75</th>
#       <th>pub_rec_bankruptcies</th>
#       <th>tax_liens</th>
#       <th>tot_hi_cred_lim</th>
#       <th>total_bal_ex_mort</th>
#       <th>total_bc_limit</th>
#       <th>total_il_high_credit_limit</th>
#       <th>revol_bal_joint</th>
#       <th>sec_app_fico_range_low</th>
#       <th>sec_app_fico_range_high</th>
#       <th>sec_app_earliest_cr_line</th>
#       <th>sec_app_inq_last_6mths</th>
#       <th>sec_app_mort_acc</th>
#       <th>sec_app_open_acc</th>
#       <th>sec_app_revol_util</th>
#       <th>sec_app_open_act_il</th>
#       <th>sec_app_num_rev_accts</th>
#       <th>sec_app_chargeoff_within_12_mths</th>
#       <th>sec_app_collections_12_mths_ex_med</th>
#       <th>sec_app_mths_since_last_major_derog</th>
#       <th>hardship_flag</th>
#       <th>hardship_type</th>
#       <th>hardship_reason</th>
#       <th>hardship_status</th>
#       <th>deferral_term</th>
#       <th>hardship_amount</th>
#       <th>hardship_start_date</th>
#       <th>hardship_end_date</th>
#       <th>payment_plan_start_date</th>
#       <th>hardship_length</th>
#       <th>hardship_dpd</th>
#       <th>hardship_loan_status</th>
#       <th>orig_projected_additional_accrued_interest</th>
#       <th>hardship_payoff_balance_amount</th>
#       <th>hardship_last_payment_amount</th>
#       <th>disbursement_method</th>
#       <th>debt_settlement_flag</th>
#       <th>debt_settlement_flag_date</th>
#       <th>settlement_status</th>
#       <th>settlement_date</th>
#       <th>settlement_amount</th>
#       <th>settlement_percentage</th>
#       <th>settlement_term</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>884869</th>
#       <td>36221446</td>
#       <td>NaN</td>
#       <td>11575</td>
#       <td>11575</td>
#       <td>11575.0</td>
#       <td>36 months</td>
#       <td>15.59%</td>
#       <td>404.61</td>
#       <td>D</td>
#       <td>D1</td>
#       <td>Manager</td>
#       <td>10+ years</td>
#       <td>RENT</td>
#       <td>25400.0</td>
#       <td>Verified</td>
#       <td>Jan-2015</td>
#       <td>0</td>
#       <td>n</td>
#       <td>https://lendingclub.com/browse/loanDetail.action?loan_id=36221446</td>
#       <td>NaN</td>
#       <td>credit_card</td>
#       <td>Credit card refinancing</td>
#       <td>791xx</td>
#       <td>TX</td>
#       <td>27.08</td>
#       <td>0</td>
#       <td>Jul-1999</td>
#       <td>680</td>
#       <td>684</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>9</td>
#       <td>0</td>
#       <td>18266</td>
#       <td>65%</td>
#       <td>18</td>
#       <td>f</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>13976.740000</td>
#       <td>13976.74</td>
#       <td>11575.00</td>
#       <td>2401.74</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>0.0000</td>
#       <td>Sep-2016</td>
#       <td>6281.14</td>
#       <td>NaN</td>
#       <td>Nov-2016</td>
#       <td>694</td>
#       <td>690</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>Individual</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>0</td>
#       <td>19798</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>28100</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>2200.0</td>
#       <td>9234.0</td>
#       <td>66.4</td>
#       <td>0</td>
#       <td>0</td>
#       <td>113.0</td>
#       <td>184</td>
#       <td>48</td>
#       <td>8</td>
#       <td>0</td>
#       <td>48.0</td>
#       <td>NaN</td>
#       <td>14.0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>7</td>
#       <td>7</td>
#       <td>7</td>
#       <td>10</td>
#       <td>5</td>
#       <td>8</td>
#       <td>13.0</td>
#       <td>7</td>
#       <td>9</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>100.0</td>
#       <td>42.9</td>
#       <td>0</td>
#       <td>0</td>
#       <td>29866</td>
#       <td>19798</td>
#       <td>27500</td>
#       <td>1766</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>N</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Cash</td>
#       <td>N</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>884870</th>
#       <td>36330911</td>
#       <td>NaN</td>
#       <td>12000</td>
#       <td>12000</td>

# %%
    # Data dimension
data.shape
# Out:
# (442601, 151)

# %% [markdown]
# ### Data wrangling

# %% [markdown]
# After studying the whole dictionary, place in `references/dictionary.md`, we saw that there are some variables that we can not use them, because is information a posteriori, some examples of these columns are: `collection_recovery_fee`, `installment`, `last_credit_pull_d`, `last_pymnt_amnt`...

# %%
    # First, we make an objetc with the information of these columns
columns = ["collection_recovery_fee", "dti", "dti_joint", "fico_range_high", "fico_range_low", "grade", "initial_list_status", 
           "installment", "last_credit_pull_d", "last_fico_range_high", "last_fico_range_low", "last_pymnt_amnt", 
           "last_pymnt_d", "loan_amnt", "mths_since_last_delinq", "mths_since_last_major_derog", "mths_since_rcnt_il", 
           "next_pymnt_d", "mths_since_recent_bc", "mths_since_recent_bc_dlq", "mths_since_recent_inq", 
           "mths_since_recent_revol_delinq", "out_prncp", "out_prncp_inv", "pymnt_plan", "recoveries", "sub_grade", 
           "tot_coll_amt", "tot_cur_bal", "total_bal_ex_mort", "total_pymnt", "total_pymnt_inv", "total_rec_int", 
           "total_rec_late_fee", "total_rec_prncp", "total_rev_hi_lim", "verification_status", "verification_status_joint",
           "issue_d", "earliest_cr_line", "hardship_flag"]

    # Then we drop those columns
data = data.drop(columns = columns)

# %% [markdown]
# Once we have viewed our dataset, we continue exploring the column types and nulls...

# %%
data.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 442601 entries, 8 to 884875
# Data columns (total 110 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   id                                          442601 non-null  int64
#  1   member_id                                   0 non-null       float64
#  2   funded_amnt                                 442601 non-null  int64
#  3   funded_amnt_inv                             442601 non-null  float64
#  4   term                                        442601 non-null  object
#  5   int_rate                                    442601 non-null  object
#  6   emp_title                                   417584 non-null  object
#  7   emp_length                                  418726 non-null  object
#  8   home_ownership                              442601 non-null  object
#  9   annual_inc                                  442601 non-null  float64
#  10  loan_status                                 442601 non-null  int64
#  11  url                                         442601 non-null  object
#  12  desc                                        14130 non-null   object
#  13  purpose                                     442601 non-null  object
#  14  title                                       442539 non-null  object
#  15  zip_code                                    442601 non-null  object
#  16  addr_state                                  442601 non-null  object
#  17  delinq_2yrs                                 442601 non-null  int64
#  18  inq_last_6mths                              442601 non-null  int64
#  19  mths_since_last_record                      83042 non-null   float64
#  20  open_acc                                    442601 non-null  int64
#  21  pub_rec                                     442601 non-null  int64
#  22  revol_bal                                   442601 non-null  int64
#  23  revol_util                                  442387 non-null  object
#  24  total_acc                                   442601 non-null  int64
#  25  collections_12_mths_ex_med                  442601 non-null  int64
#  26  policy_code                                 442601 non-null  int64
#  27  application_type                            442601 non-null  object
#  28  annual_inc_joint                            1018 non-null    float64
#  29  acc_now_delinq                              442601 non-null  int64
#  30  open_acc_6m                                 24789 non-null   float64
#  31  open_act_il                                 24789 non-null   float64
#  32  open_il_12m                                 24789 non-null   float64
#  33  open_il_24m                                 24789 non-null   float64
#  34  total_bal_il                                24789 non-null   float64
#  35  il_util                                     21570 non-null   float64
#  36  open_rv_12m                                 24789 non-null   float64
#  37  open_rv_24m                                 24789 non-null   float64
#  38  max_bal_bc                                  24789 non-null   float64
#  39  all_util                                    24786 non-null   float64
#  40  inq_fi                                      24789 non-null   float64
#  41  total_cu_tl                                 24789 non-null   float64
#  42  inq_last_12m                                24789 non-null   float64
#  43  acc_open_past_24mths                        442601 non-null  int64
#  44  avg_cur_bal                                 442595 non-null  float64
#  45  bc_open_to_buy                              437992 non-null  float64
#  46  bc_util                                     437683 non-null  float64
#  47  chargeoff_within_12_mths                    442601 non-null  int64
#  48  delinq_amnt                                 442601 non-null  int64
#  49  mo_sin_old_il_acct                          429920 non-null  float64
#  50  mo_sin_old_rev_tl_op                        442601 non-null  int64
#  51  mo_sin_rcnt_rev_tl_op                       442601 non-null  int64
#  52  mo_sin_rcnt_tl                              442601 non-null  int64
#  53  mort_acc                                    442601 non-null  int64
#  54  num_accts_ever_120_pd                       442601 non-null  int64
#  55  num_actv_bc_tl                              442601 non-null  int64
#  56  num_actv_rev_tl                             442601 non-null  int64
#  57  num_bc_sats                                 442601 non-null  int64
#  58  num_bc_tl                                   442601 non-null  int64
#  59  num_il_tl                                   442601 non-null  int64
#  60  num_op_rev_tl                               442601 non-null  int64
#  61  num_rev_accts                               442600 non-null  float64
#  62  num_rev_tl_bal_gt_0                         442601 non-null  int64
#  63  num_sats                                    442601 non-null  int64
#  64  num_tl_120dpd_2m                            424335 non-null  float64
#  65  num_tl_30dpd                                442601 non-null  int64
#  66  num_tl_90g_dpd_24m                          442601 non-null  int64
#  67  num_tl_op_past_12m                          442601 non-null  int64
#  68  pct_tl_nvr_dlq                              442601 non-null  float64
#  69  percent_bc_gt_75                            437728 non-null  float64
#  70  pub_rec_bankruptcies                        442601 non-null  int64
#  71  tax_liens                                   442601 non-null  int64
#  72  tot_hi_cred_lim                             442601 non-null  int64
#  73  total_bc_limit                              442601 non-null  int64
#  74  total_il_high_credit_limit                  442601 non-null  int64
#  75  revol_bal_joint                             800 non-null     float64
#  76  sec_app_fico_range_low                      800 non-null     float64
#  77  sec_app_fico_range_high                     800 non-null     float64
#  78  sec_app_earliest_cr_line                    800 non-null     object
#  79  sec_app_inq_last_6mths                      800 non-null     float64
#  80  sec_app_mort_acc                            800 non-null     float64
#  81  sec_app_open_acc                            800 non-null     float64
#  82  sec_app_revol_util                          786 non-null     float64
#  83  sec_app_open_act_il                         800 non-null     float64
#  84  sec_app_num_rev_accts                       800 non-null     float64
#  85  sec_app_chargeoff_within_12_mths            800 non-null     float64
#  86  sec_app_collections_12_mths_ex_med          800 non-null     float64
#  87  sec_app_mths_since_last_major_derog         273 non-null     float64
#  88  hardship_type                               278 non-null     object
#  89  hardship_reason                             278 non-null     object
#  90  hardship_status                             278 non-null     object
#  91  deferral_term                               278 non-null     float64
#  92  hardship_amount                             278 non-null     float64
#  93  hardship_start_date                         278 non-null     object
#  94  hardship_end_date                           278 non-null     object
#  95  payment_plan_start_date                     278 non-null     object
#  96  hardship_length                             278 non-null     float64
#  97  hardship_dpd                                278 non-null     float64
#  98  hardship_loan_status                        278 non-null     object
#  99  orig_projected_additional_accrued_interest  61 non-null      float64
#  100 hardship_payoff_balance_amount              278 non-null     float64
#  101 hardship_last_payment_amount                278 non-null     float64
#  102 disbursement_method                         442601 non-null  object
#  103 debt_settlement_flag                        442601 non-null  object
#  104 debt_settlement_flag_date                   8137 non-null    object
#  105 settlement_status                           8137 non-null    object
#  106 settlement_date                             8137 non-null    object
#  107 settlement_amount                           8137 non-null    float64
#  108 settlement_percentage                       8137 non-null    float64
#  109 settlement_term                             8137 non-null    float64
# dtypes: float64(48), int64(36), object(26)
# memory usage: 374.8+ MB

# %% [markdown]
# As we can see above we have plenty of columns with nulls, so we are going to drop those columns which more than a 75% of the information is null.

# %%
    # For this operation we will use drop.na(), but firstly we will create an objet with the scale
thresh = round(len(data) * 0.75) 

data = data.dropna(thresh = thresh, axis = 1)

    #Lets check the data shape
data.shape
# Out:
# (442601, 60)

# %% [markdown]
# We can see that now we have only 64 columns, instead of 151. This is a huge reduction of the variables, but we continue having too much, in order to reduce them, we will study which of them are important in order to predict `loan_status`.

# %% [markdown]
# Other method we can use in order to select those variables which are important is, we could use a correlation matrix and select those whith hight correlation values, but with 65 columns will be too difficult... so we will use a smarter way:
#
# *Select those variables with more than 80% of correlation between them and drop them*

# %%
    # To start, we create our objet called "correlated_features" and our correlation parameter
correlated_features = set()
corr_param = 0.8

    # Them, we drop our predict variable
correlation_matrix = data.drop('loan_status', axis=1).corr()

    # Finally we use a loop
for i in range(len(correlation_matrix.columns)):
        for j in range(i):
            if abs(correlation_matrix.iloc[i, j]) > corr_param:
                colname = correlation_matrix.columns[i]
                correlated_features.add(colname)

correlated_features
# Out:
# {'funded_amnt_inv',
#  'num_bc_sats',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_30dpd',
#  'percent_bc_gt_75',
#  'tot_hi_cred_lim',
#  'total_bc_limit'}

# %%
data = data.drop(correlated_features, axis = 1)

# %% [markdown]
# Now we will drop those columns which are not important to predict `loan_status`, using our business knowlege, some examples of them are `url`, `policy_code`, `title`, `purpose`...

# %%
    # First, we make an objetc with the information of these columns
columns = ["emp_title", "id", "policy_code", "purpose", "title", "url", "zip_code"]

    # Then we drop those columns
data = data.drop(columns = columns)

    # Check the dataset
data.shape
# Out:
# (442601, 43)

# %% [markdown]
# ### Recursive Featuring Elimination

# %% [markdown]
# As we can see we have reduced the dataset a 33% but we still have to much columns, so, we are going to use RFE (Recursive Featuring Elimination) algorithm that *is basically a backward selection of the predictors. This technique begins by building a model on the entire set of predictors and computing an importance score for each predictor. The least important predictor(s) are then removed, the model is re-built, and importance scores are computed again. In practice, the analyst specifies the number of predictor subsets to evaluate as well as each subset’s size. Therefore, the subset size is a tuning parameter for RFE. The subset size that optimizes the performance criteria is used to select the predictors based on the importance rankings. The optimal subset is then used to train the final model.*

# %% [markdown]
# First of all, in order to run this algorithm we have to modify the columns types because it is a must to codify the categorical variables. Therefore, we will move forward analysing those columns that could changed for categorical and those that have symbols that could affect the code in a next step.

# %% [markdown]
# - `int_rate`, `revol_util`: Lets delete the "%" and convert the variable into a float object
#
# - `emp_length`, `home_ownership`, `term`, **`loan_status`**, `addr_state`, `application_type`, `disbursement_method`, `debt_settlement_flag`: Codify

# %%
    # With a apply and lamba function we, in the same line, convert the variable into a float and we drop the last 
    # element.
data['int_rate'] = data['int_rate'].apply(lambda x: float(x[:-1]))

# %%
    # Now, we convert the revol_util variable into an string object and the apply the same lamba function as above
data['revol_util'] = data['revol_util'].astype('category')
data['revol_util'] = data['revol_util'].apply(lambda x: x[:-1])
data['revol_util'] = data['revol_util'].astype('float64')

# %%
    # We create and object we those variable that we want to convert into a categorical named columns_categ
columns_categ = ["emp_length", "home_ownership", "loan_status", "addr_state", "application_type", "term",
                 "disbursement_method", "debt_settlement_flag"]
    
    # Below, we transform the variables into categorical with the astype function.
data[columns_categ] = data[columns_categ].astype('category')

# %%
    #with a lambda and apply function we convert the different categories into the variable to a number 
data[columns_categ] = data[columns_categ].apply(lambda x: x.cat.codes)

# %% [markdown]
# Now, lets check the results of the functions created above

# %%
display(HTML(data.head().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>funded_amnt</th>
#       <th>term</th>
#       <th>int_rate</th>
#       <th>emp_length</th>
#       <th>home_ownership</th>
#       <th>annual_inc</th>
#       <th>loan_status</th>
#       <th>addr_state</th>
#       <th>delinq_2yrs</th>
#       <th>inq_last_6mths</th>
#       <th>open_acc</th>
#       <th>pub_rec</th>
#       <th>revol_bal</th>
#       <th>revol_util</th>
#       <th>total_acc</th>
#       <th>collections_12_mths_ex_med</th>
#       <th>application_type</th>
#       <th>acc_now_delinq</th>
#       <th>acc_open_past_24mths</th>
#       <th>avg_cur_bal</th>
#       <th>bc_open_to_buy</th>
#       <th>bc_util</th>
#       <th>chargeoff_within_12_mths</th>
#       <th>delinq_amnt</th>
#       <th>mo_sin_old_il_acct</th>
#       <th>mo_sin_old_rev_tl_op</th>
#       <th>mo_sin_rcnt_rev_tl_op</th>
#       <th>mo_sin_rcnt_tl</th>
#       <th>mort_acc</th>
#       <th>num_accts_ever_120_pd</th>
#       <th>num_actv_bc_tl</th>
#       <th>num_actv_rev_tl</th>
#       <th>num_bc_tl</th>
#       <th>num_il_tl</th>
#       <th>num_tl_120dpd_2m</th>
#       <th>num_tl_90g_dpd_24m</th>
#       <th>num_tl_op_past_12m</th>
#       <th>pct_tl_nvr_dlq</th>
#       <th>pub_rec_bankruptcies</th>
#       <th>tax_liens</th>
#       <th>total_il_high_credit_limit</th>
#       <th>disbursement_method</th>
#       <th>debt_settlement_flag</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8</th>
#       <td>11575</td>
#       <td>0</td>
#       <td>7.35</td>
#       <td>6</td>
#       <td>2</td>
#       <td>153000.0</td>
#       <td>0</td>
#       <td>4</td>
#       <td>0</td>
#       <td>0</td>
#       <td>20</td>
#       <td>1</td>
#       <td>8550</td>
#       <td>22.7</td>
#       <td>46</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>8</td>
#       <td>23302.0</td>
#       <td>24269.0</td>
#       <td>13.6</td>
#       <td>0</td>
#       <td>0</td>
#       <td>130.0</td>
#       <td>275</td>
#       <td>3</td>
#       <td>3</td>
#       <td>2</td>
#       <td>0</td>
#       <td>6</td>
#       <td>9</td>
#       <td>16</td>
#       <td>12</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>95.7</td>
#       <td>1</td>
#       <td>0</td>
#       <td>120572</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>7200</td>
#       <td>0</td>
#       <td>24.85</td>
#       <td>2</td>
#       <td>3</td>
#       <td>50000.0</td>
#       <td>0</td>
#       <td>47</td>
#       <td>0</td>
#       <td>0</td>
#       <td>4</td>
#       <td>0</td>
#       <td>3560</td>
#       <td>98.9</td>
#       <td>5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>1863.0</td>
#       <td>40.0</td>
#       <td>98.9</td>
#       <td>0</td>
#       <td>0</td>
#       <td>21.0</td>
#       <td>172</td>
#       <td>14</td>
#       <td>14</td>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>80.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>4000</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>7500</td>
#       <td>0</td>
#       <td>7.35</td>
#       <td>7</td>
#       <td>1</td>
#       <td>110000.0</td>
#       <td>0</td>
#       <td>43</td>
#       <td>0</td>
#       <td>2</td>
#       <td>19</td>
#       <td>0</td>
#       <td>23348</td>
#       <td>27.2</td>
#       <td>27</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>13</td>
#       <td>14551.0</td>
#       <td>60352.0</td>
#       <td>27.9</td>
#       <td>0</td>
#       <td>0</td>
#       <td>48.0</td>
#       <td>51</td>
#       <td>3</td>
#       <td>3</td>
#       <td>4</td>
#       <td>0</td>
#       <td>11</td>
#       <td>11</td>
#       <td>13</td>
#       <td>8</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>100.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>32239</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>10000</td>
#       <td>1</td>
#       <td>16.02</td>
#       <td>7</td>
#       <td>3</td>
#       <td>51979.0</td>
#       <td>0</td>
#       <td>4</td>
#       <td>0</td>
#       <td>0</td>
#       <td>15</td>
#       <td>2</td>
#       <td>5733</td>
#       <td>20.0</td>
#       <td>21</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>7</td>
#       <td>730.0</td>
#       <td>14628.0</td>
#       <td>22.2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>130.0</td>
#       <td>54</td>
#       <td>6</td>
#       <td>6</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>7</td>
#       <td>8</td>
#       <td>4</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>100.0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>5500</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>14000</td>
#       <td>0</td>
#       <td>16.02</td>
#       <td>7</td>
#       <td>1</td>
#       <td>75000.0</td>
#       <td>0</td>
#       <td>19</td>
#       <td>1</td>
#       <td>0</td>
#       <td>4</td>
#       <td>0</td>
#       <td>2700</td>
#       <td>90.0</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>5</td>
#       <td>31911.0</td>
#       <td>300.0</td>
#       <td>90.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>109.0</td>
#       <td>97</td>
#       <td>5</td>
#       <td>5</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>5</td>
#       <td>3</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>90.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>30321</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# To move forward with the RFE algorithm we need to drop the NaN's because it doesn't run with them, so let use the dropna function.

# %%
data = data.dropna() 
data.shape
# Out:
# (407319, 43)

# %% [markdown]
# As we can observe, we change from 442567 rows to 407319.

# %% [markdown]
# #### Feature scaling

# %%
data.select_dtypes(include = ['float64', 'int64']).columns
# Out:
# Index(['funded_amnt', 'int_rate', 'annual_inc', 'delinq_2yrs',
#        'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'collections_12_mths_ex_med', 'acc_now_delinq',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
#        'mort_acc', 'num_accts_ever_120_pd', 'num_actv_bc_tl',
#        'num_actv_rev_tl', 'num_bc_tl', 'num_il_tl', 'num_tl_120dpd_2m',
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'pub_rec_bankruptcies', 'tax_liens', 'total_il_high_credit_limit'],
#       dtype='object')

# %%
     # Instance of preprocessing
scl = preprocessing.StandardScaler()

    # Take numeric columns
columns = ['funded_amnt', 'int_rate', 'annual_inc', 'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 
           'revol_util', 'total_acc', 'collections_12_mths_ex_med', 'acc_now_delinq', 'acc_open_past_24mths', 'avg_cur_bal', 
           'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op',
           'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 
           'num_bc_tl', 'num_il_tl', 'num_tl_120dpd_2m', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
           'pub_rec_bankruptcies', 'tax_liens', 'total_il_high_credit_limit']

    # Apply function
data[columns] = scl.fit_transform(data[columns])

    # Chech results
display(HTML(data.head().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>funded_amnt</th>
#       <th>term</th>
#       <th>int_rate</th>
#       <th>emp_length</th>
#       <th>home_ownership</th>
#       <th>annual_inc</th>
#       <th>loan_status</th>
#       <th>addr_state</th>
#       <th>delinq_2yrs</th>
#       <th>inq_last_6mths</th>
#       <th>open_acc</th>
#       <th>pub_rec</th>
#       <th>revol_bal</th>
#       <th>revol_util</th>
#       <th>total_acc</th>
#       <th>collections_12_mths_ex_med</th>
#       <th>application_type</th>
#       <th>acc_now_delinq</th>
#       <th>acc_open_past_24mths</th>
#       <th>avg_cur_bal</th>
#       <th>bc_open_to_buy</th>
#       <th>bc_util</th>
#       <th>chargeoff_within_12_mths</th>
#       <th>delinq_amnt</th>
#       <th>mo_sin_old_il_acct</th>
#       <th>mo_sin_old_rev_tl_op</th>
#       <th>mo_sin_rcnt_rev_tl_op</th>
#       <th>mo_sin_rcnt_tl</th>
#       <th>mort_acc</th>
#       <th>num_accts_ever_120_pd</th>
#       <th>num_actv_bc_tl</th>
#       <th>num_actv_rev_tl</th>
#       <th>num_bc_tl</th>
#       <th>num_il_tl</th>
#       <th>num_tl_120dpd_2m</th>
#       <th>num_tl_90g_dpd_24m</th>
#       <th>num_tl_op_past_12m</th>
#       <th>pct_tl_nvr_dlq</th>
#       <th>pub_rec_bankruptcies</th>
#       <th>tax_liens</th>
#       <th>total_il_high_credit_limit</th>
#       <th>disbursement_method</th>
#       <th>debt_settlement_flag</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8</th>
#       <td>-0.374080</td>
#       <td>0</td>
#       <td>-1.295542</td>
#       <td>6</td>
#       <td>2</td>
#       <td>1.165720</td>
#       <td>0</td>
#       <td>4</td>
#       <td>-0.374147</td>
#       <td>-0.706388</td>
#       <td>1.472352</td>
#       <td>1.225871</td>
#       <td>-0.361733</td>
#       <td>-1.274618</td>
#       <td>1.620425</td>
#       <td>-0.118374</td>
#       <td>0</td>
#       <td>-0.071803</td>
#       <td>1.008902</td>
#       <td>0.632728</td>
#       <td>1.005441</td>
#       <td>-1.730262</td>
#       <td>-0.091285</td>
#       <td>-0.017873</td>
#       <td>0.073228</td>
#       <td>1.015729</td>
#       <td>-0.615098</td>
#       <td>-0.558955</td>
#       <td>0.100821</td>
#       <td>-0.409628</td>
#       <td>1.098916</td>
#       <td>1.060693</td>
#       <td>1.558178</td>
#       <td>0.391566</td>
#       <td>-0.028161</td>
#       <td>-0.18264</td>
#       <td>-0.122448</td>
#       <td>0.151335</td>
#       <td>2.227071</td>
#       <td>-0.135221</td>
#       <td>1.811281</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>-0.888360</td>
#       <td>0</td>
#       <td>2.596361</td>
#       <td>2</td>
#       <td>3</td>
#       <td>-0.401111</td>
#       <td>0</td>
#       <td>47</td>
#       <td>-0.374147</td>
#       <td>-0.706388</td>
#       <td>-1.465798</td>
#       <td>-0.361022</td>
#       <td>-0.591312</td>
#       <td>1.923440</td>
#       <td>-1.772693</td>
#       <td>-0.118374</td>
#       <td>0</td>
#       <td>-0.071803</td>
#       <td>-0.897198</td>
#       <td>-0.735431</td>
#       <td>-0.648872</td>
#       <td>1.344423</td>
#       <td>-0.091285</td>
#       <td>-0.017873</td>
#       <td>-2.043405</td>
#       <td>-0.104311</td>
#       <td>0.091684</td>
#       <td>0.812923</td>
#       <td>-0.857378</td>
#       <td>0.329330</td>
#       <td>-0.765412</td>
#       <td>-1.161177</td>
#       <td>-1.122894</td>
#       <td>-1.079178</td>
#       <td>-0.028161</td>
#       <td>-0.18264</td>
#       <td>-1.233873</td>
#       <td>-1.770156</td>
#       <td>-0.352937</td>
#       <td>-0.135221</td>
#       <td>-0.915202</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>-0.853095</td>
#       <td>0</td>
#       <td>-1.295542</td>
#       <td>7</td>
#       <td>1</td>
#       <td>0.511606</td>
#       <td>0</td>
#       <td>43</td>
#       <td>-0.374147</td>
#       <td>1.403049</td>
#       <td>1.288718</td>
#       <td>-0.361022</td>
#       <td>0.319091</td>
#       <td>-1.085757</td>
#       <td>0.048005</td>
#       <td>-0.118374</td>
#       <td>0</td>
#       <td>-0.071803</td>
#       <td>2.597318</td>
#       <td>0.074271</td>
#       <td>3.469124</td>
#       <td>-1.214811</td>
#       <td>-0.091285</td>
#       <td>-0.017873</td>
#       <td>-1.519101</td>
#       <td>-1.420086</td>
#       <td>-0.615098</td>
#       <td>-0.558955</td>
#       <td>1.059021</td>
#       <td>-0.409628</td>
#       <td>3.429325</td>
#       <td>1.695513</td>
#       <td>0.939469</td>
#       <td>-0.143250</td>
#       <td>-0.028161</td>
#       <td>-0.18264</td>
#       <td>0.433265</td>
#       <td>0.677603</td>
#       <td>-0.352937</td>
#       <td>-0.135221</td>
#       <td>-0.254725</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>-0.559221</td>
#       <td>1</td>
#       <td>0.632618</td>
#       <td>7</td>
#       <td>3</td>
#       <td>-0.371006</td>
#       <td>0</td>
#       <td>4</td>
#       <td>-0.374147</td>
#       <td>-0.706388</td>
#       <td>0.554180</td>
#       <td>2.812763</td>
#       <td>-0.491337</td>
#       <td>-1.387935</td>
#       <td>-0.448549</td>
#       <td>-0.118374</td>
#       <td>0</td>
#       <td>-0.071803</td>
#       <td>0.691219</td>
#       <td>-0.807735</td>
#       <td>0.347170</td>
#       <td>-1.420270</td>
#       <td>-0.091285</td>
#       <td>-0.017873</td>
#       <td>0.073228</td>
#       <td>-1.387463</td>
#       <td>-0.422339</td>
#       <td>-0.184807</td>
#       <td>-0.857378</td>
#       <td>-0.409628</td>
#       <td>-0.299330</td>
#       <td>0.425873</td>
#       <td>-0.091712</td>
#       <td>-0.678066</td>
#       <td>-0.028161</td>
#       <td>-0.18264</td>
#       <td>0.433265</td>
#       <td>0.677603</td>
#       <td>4.807080</td>
#       <td>-0.135221</td>
#       <td>-0.880119</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>-0.089022</td>
#       <td>0</td>
#       <td>0.632618</td>
#       <td>7</td>
#       <td>1</td>
#       <td>-0.020812</td>
#       <td>0</td>
#       <td>19</td>
#       <td>0.748500</td>
#       <td>-0.706388</td>
#       <td>-1.465798</td>
#       <td>-0.361022</td>
#       <td>-0.630879</td>
#       <td>1.549914</td>
#       <td>-1.358898</td>
#       <td>-0.118374</td>
#       <td>0</td>
#       <td>-0.071803</td>
#       <td>0.055852</td>
#       <td>1.182123</td>
#       <td>-0.631120</td>
#       <td>1.023618</td>
#       <td>-0.091285</td>
#       <td>-0.017873</td>
#       <td>-0.334563</td>
#       <td>-0.919874</td>
#       <td>-0.486592</td>
#       <td>-0.309523</td>
#       <td>-0.378278</td>
#       <td>-0.409628</td>
#       <td>-1.231494</td>
#       <td>-1.478587</td>
#       <td>-0.710421</td>
#       <td>-0.811770</td>
#       <td>-0.028161</td>
#       <td>-0.18264</td>
#       <td>0.433265</td>
#       <td>-0.546277</td>
#       <td>-0.352937</td>
#       <td>-0.135221</td>
#       <td>-0.299585</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Due to the RFE algorithm it's so intensive in compute, and therefore expend to much time to drop the results we will work, at this stage, with a sample of 1000 random rows.

# %%
    # With the sample function, we create the sample with a seed and with replacement
minidata = data.sample(n = 1000, replace = True, random_state = 1322)

# %%
minidata.shape  #lets check the results
# Out:
# (1000, 43)

# %% [markdown]
# Finally, we can start with the RFE algorithm to select the variables

# %%
'''
X: it is the minidata df with the independent variables
target: it is the vector with the dependent variable
'''

X = minidata.drop('loan_status', axis=1)
target = minidata['loan_status']

# %%
'''
rfc: it is the object that contains the RandomForestClassifier that we will use in the RFECV.
'''
rfc = RandomForestClassifier(random_state=1322)

# %%
'''
rfecv: it is an RFE with Cross Validation. 
    Parameters:
        Estimator = the object rfc created above that contains the information about the feature importance
        step = number of features to remove at each iteration
        cv = currently, we are using a StratifiedKFold cross validation with k equals to 10
        scoring = the metric chosen.
'''

rfecv = RFECV(estimator = rfc, step = 1, cv = StratifiedKFold(10), scoring = 'accuracy')

'''
rfecv.fit: this function fitted the predictive variable according to our model
'''

rfecv.fit(X, target)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=10, random_state=None, shuffle=False),
#       estimator=RandomForestClassifier(random_state=1322), scoring='accuracy')

# %% [markdown]
# Once the execution finishes, you can use this line of code to see how many features are optimal to produce the best accuracy (or whatever your chosen metric is):

# %%
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# Optimal number of features: 29

# %% [markdown]
# Not only this, but you can also plot the accuracy obtained with every number of features used:

# %%
plt.figure(figsize=(16, 9))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('% Correct Classification', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_, color = 'darkred', linewidth=3)

plt.show()

# %% [markdown]
# It is visible that with 29 features the accuracy was close to 80%, which is very good taking account that we initially have 150 variables.
#
# You can also print out which features are considered to be least important and drop them with this snippet:

# %%
print(np.where(rfecv.support_ == False)[0])

X.drop(X.columns[np.where(rfecv.support_ == False)[0]], axis=1, inplace=True)
# Out:
# [ 7 10 14 15 16 21 22 28 33 34 37 38 40]

# %% [markdown]
# The instance of RFECV has also a nifty feature_importances attribute which is worthy to be checked out

# %%
rfecv.estimator_.feature_importances_
# Out:
# array([0.04491496, 0.02587055, 0.07495176, 0.02379788, 0.01229263,
#        0.04876568, 0.03110402, 0.01802166, 0.03316023, 0.04312987,
#        0.03865779, 0.03532808, 0.02413679, 0.04892717, 0.04323466,
#        0.039355  , 0.0422191 , 0.04906691, 0.03195014, 0.02952012,
#        0.02075663, 0.0209414 , 0.02955821, 0.02643509, 0.0287237 ,
#        0.01867239, 0.02565494, 0.04469301, 0.04615961])

# %% [markdown]
# Okay, okay, don’t scream at me just yet. I know that this doesn’t tell you much. Thankfully, this is pretty easy to visualize. One way is to create a DataFrame object with attributes as one column and the importance as the other, and then just simply sort the DataFrame by importance in descending order. Then you can use the power of plotting libraries such as Matplotlib to draw a Bar chart (horizontal is preferred for this scenario) to get a nice visual representation. Here’s the code for doing so:

# %%
'''
Firstly, we create an emplty df.
Second, we create two columns. One for the variables names and another with the % importance of each.

Finnaly, we sort them in ascending order.
'''

df_viz = pd.DataFrame()
df_viz['attr'] = X.columns
df_viz['importance'] = rfecv.estimator_.feature_importances_

df_viz = df_viz.sort_values(by='importance', ascending=True)

    # Bar Plot
plt.figure(figsize = (10, 15))
plt.barh(y = df_viz['attr'], width = df_viz['importance'], color = 'orangered', edgecolor = 'firebrick')
plt.title('RFECV - Feature Importances', fontsize = 15, fontweight = 'bold')
plt.xlabel('Importance', fontsize = 15)
plt.show()

# %% [markdown]
# At this stage, the most important variable is the int_rate(`interest rate`), this make sense because when we have a client with high interest rate, this is due to a high risk. The interest rate depends of the total amount of the loan, the term, the `emp_title`, `emp_length`... so on.
#
# The number of mortage accounts (`mort_acc`) it isn't signicate explaining the loaning state. That is a little weird because a person with multiple mortage account could be a risky customer and probably a default borrower.

# %% [markdown]
# ***

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# In statistics, exploratory data analysis is an approach to analyzing data sets to summarize their main characteristics, often with visual methods. A statistical model can be used or not, but primarily EDA is for seeing what the data can tell us beyond the formal modeling or hypothesis testing task.

# %%
    # Select the columns of the RFECV
columns = ['loan_status', 'funded_amnt', 'term', 'int_rate', 'emp_length', 'home_ownership', 'annual_inc', 'addr_state', 
           'inq_last_6mths', 'open_acc', 'revol_bal', 'revol_util', 'total_acc', 'acc_open_past_24mths', 'avg_cur_bal',
           'bc_open_to_buy', 'bc_util', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
           'mort_acc', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_tl', 'num_il_tl', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
           'total_il_high_credit_limit', 'debt_settlement_flag']

    # Create a new dataset
dataset = data[columns]

    # View data
display(HTML(dataset.head().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>loan_status</th>
#       <th>funded_amnt</th>
#       <th>term</th>
#       <th>int_rate</th>
#       <th>emp_length</th>
#       <th>home_ownership</th>
#       <th>annual_inc</th>
#       <th>addr_state</th>
#       <th>inq_last_6mths</th>
#       <th>open_acc</th>
#       <th>revol_bal</th>
#       <th>revol_util</th>
#       <th>total_acc</th>
#       <th>acc_open_past_24mths</th>
#       <th>avg_cur_bal</th>
#       <th>bc_open_to_buy</th>
#       <th>bc_util</th>
#       <th>mo_sin_old_il_acct</th>
#       <th>mo_sin_old_rev_tl_op</th>
#       <th>mo_sin_rcnt_rev_tl_op</th>
#       <th>mo_sin_rcnt_tl</th>
#       <th>mort_acc</th>
#       <th>num_actv_bc_tl</th>
#       <th>num_actv_rev_tl</th>
#       <th>num_bc_tl</th>
#       <th>num_il_tl</th>
#       <th>num_tl_op_past_12m</th>
#       <th>pct_tl_nvr_dlq</th>
#       <th>total_il_high_credit_limit</th>
#       <th>debt_settlement_flag</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8</th>
#       <td>0</td>
#       <td>-0.374080</td>
#       <td>0</td>
#       <td>-1.295542</td>
#       <td>6</td>
#       <td>2</td>
#       <td>1.165720</td>
#       <td>4</td>
#       <td>-0.706388</td>
#       <td>1.472352</td>
#       <td>-0.361733</td>
#       <td>-1.274618</td>
#       <td>1.620425</td>
#       <td>1.008902</td>
#       <td>0.632728</td>
#       <td>1.005441</td>
#       <td>-1.730262</td>
#       <td>0.073228</td>
#       <td>1.015729</td>
#       <td>-0.615098</td>
#       <td>-0.558955</td>
#       <td>0.100821</td>
#       <td>1.098916</td>
#       <td>1.060693</td>
#       <td>1.558178</td>
#       <td>0.391566</td>
#       <td>-0.122448</td>
#       <td>0.151335</td>
#       <td>1.811281</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0</td>
#       <td>-0.888360</td>
#       <td>0</td>
#       <td>2.596361</td>
#       <td>2</td>
#       <td>3</td>
#       <td>-0.401111</td>
#       <td>47</td>
#       <td>-0.706388</td>
#       <td>-1.465798</td>
#       <td>-0.591312</td>
#       <td>1.923440</td>
#       <td>-1.772693</td>
#       <td>-0.897198</td>
#       <td>-0.735431</td>
#       <td>-0.648872</td>
#       <td>1.344423</td>
#       <td>-2.043405</td>
#       <td>-0.104311</td>
#       <td>0.091684</td>
#       <td>0.812923</td>
#       <td>-0.857378</td>
#       <td>-0.765412</td>
#       <td>-1.161177</td>
#       <td>-1.122894</td>
#       <td>-1.079178</td>
#       <td>-1.233873</td>
#       <td>-1.770156</td>
#       <td>-0.915202</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>0</td>
#       <td>-0.853095</td>
#       <td>0</td>
#       <td>-1.295542</td>
#       <td>7</td>
#       <td>1</td>
#       <td>0.511606</td>
#       <td>43</td>
#       <td>1.403049</td>
#       <td>1.288718</td>
#       <td>0.319091</td>
#       <td>-1.085757</td>
#       <td>0.048005</td>
#       <td>2.597318</td>
#       <td>0.074271</td>
#       <td>3.469124</td>
#       <td>-1.214811</td>
#       <td>-1.519101</td>
#       <td>-1.420086</td>
#       <td>-0.615098</td>
#       <td>-0.558955</td>
#       <td>1.059021</td>
#       <td>3.429325</td>
#       <td>1.695513</td>
#       <td>0.939469</td>
#       <td>-0.143250</td>
#       <td>0.433265</td>
#       <td>0.677603</td>
#       <td>-0.254725</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>0</td>
#       <td>-0.559221</td>
#       <td>1</td>
#       <td>0.632618</td>
#       <td>7</td>
#       <td>3</td>
#       <td>-0.371006</td>
#       <td>4</td>
#       <td>-0.706388</td>
#       <td>0.554180</td>
#       <td>-0.491337</td>
#       <td>-1.387935</td>
#       <td>-0.448549</td>
#       <td>0.691219</td>
#       <td>-0.807735</td>
#       <td>0.347170</td>
#       <td>-1.420270</td>
#       <td>0.073228</td>
#       <td>-1.387463</td>
#       <td>-0.422339</td>
#       <td>-0.184807</td>
#       <td>-0.857378</td>
#       <td>-0.299330</td>
#       <td>0.425873</td>
#       <td>-0.091712</td>
#       <td>-0.678066</td>
#       <td>0.433265</td>
#       <td>0.677603</td>
#       <td>-0.880119</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>0</td>
#       <td>-0.089022</td>
#       <td>0</td>
#       <td>0.632618</td>
#       <td>7</td>
#       <td>1</td>
#       <td>-0.020812</td>
#       <td>19</td>
#       <td>-0.706388</td>
#       <td>-1.465798</td>
#       <td>-0.630879</td>
#       <td>1.549914</td>
#       <td>-1.358898</td>
#       <td>0.055852</td>
#       <td>1.182123</td>
#       <td>-0.631120</td>
#       <td>1.023618</td>
#       <td>-0.334563</td>
#       <td>-0.919874</td>
#       <td>-0.486592</td>
#       <td>-0.309523</td>
#       <td>-0.378278</td>
#       <td>-1.231494</td>
#       <td>-1.478587</td>
#       <td>-0.710421</td>
#       <td>-0.811770</td>
#       <td>0.433265</td>
#       <td>-0.546277</td>
#       <td>-0.299585</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now, we will check the data info.

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 407319 entries, 8 to 884875
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_status                 407319 non-null  int8
#  1   funded_amnt                 407319 non-null  float64
#  2   term                        407319 non-null  int8
#  3   int_rate                    407319 non-null  float64
#  4   emp_length                  407319 non-null  int8
#  5   home_ownership              407319 non-null  int8
#  6   annual_inc                  407319 non-null  float64
#  7   addr_state                  407319 non-null  int8
#  8   inq_last_6mths              407319 non-null  float64
#  9   open_acc                    407319 non-null  float64
#  10  revol_bal                   407319 non-null  float64
#  11  revol_util                  407319 non-null  float64
#  12  total_acc                   407319 non-null  float64
#  13  acc_open_past_24mths        407319 non-null  float64
#  14  avg_cur_bal                 407319 non-null  float64
#  15  bc_open_to_buy              407319 non-null  float64
#  16  bc_util                     407319 non-null  float64
#  17  mo_sin_old_il_acct          407319 non-null  float64
#  18  mo_sin_old_rev_tl_op        407319 non-null  float64
#  19  mo_sin_rcnt_rev_tl_op       407319 non-null  float64
#  20  mo_sin_rcnt_tl              407319 non-null  float64
#  21  mort_acc                    407319 non-null  float64
#  22  num_actv_bc_tl              407319 non-null  float64
#  23  num_actv_rev_tl             407319 non-null  float64
#  24  num_bc_tl                   407319 non-null  float64
#  25  num_il_tl                   407319 non-null  float64
#  26  num_tl_op_past_12m          407319 non-null  float64
#  27  pct_tl_nvr_dlq              407319 non-null  float64
#  28  total_il_high_credit_limit  407319 non-null  float64
#  29  debt_settlement_flag        407319 non-null  int8
# dtypes: float64(24), int8(6)
# memory usage: 80.0 MB

# %% [markdown]
# We can see that some of theme are not in the correct type, so we will modify them.

# %%
dataset = dataset.copy()
    # We create and object we those variable that we want to convert into a categorical named columns_categ
columns_categ = ['loan_status', 'term', 'home_ownership', 'emp_length', 'addr_state', 'debt_settlement_flag']
    
    # Below, we transform the variables into categorical with the astype function.
dataset[columns_categ] = dataset[columns_categ].astype('category')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 407319 entries, 8 to 884875
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_status                 407319 non-null  category
#  1   funded_amnt                 407319 non-null  float64
#  2   term                        407319 non-null  category
#  3   int_rate                    407319 non-null  float64
#  4   emp_length                  407319 non-null  category
#  5   home_ownership              407319 non-null  category
#  6   annual_inc                  407319 non-null  float64
#  7   addr_state                  407319 non-null  category
#  8   inq_last_6mths              407319 non-null  float64
#  9   open_acc                    407319 non-null  float64
#  10  revol_bal                   407319 non-null  float64
#  11  revol_util                  407319 non-null  float64
#  12  total_acc                   407319 non-null  float64
#  13  acc_open_past_24mths        407319 non-null  float64
#  14  avg_cur_bal                 407319 non-null  float64
#  15  bc_open_to_buy              407319 non-null  float64
#  16  bc_util                     407319 non-null  float64
#  17  mo_sin_old_il_acct          407319 non-null  float64
#  18  mo_sin_old_rev_tl_op        407319 non-null  float64
#  19  mo_sin_rcnt_rev_tl_op       407319 non-null  float64
#  20  mo_sin_rcnt_tl              407319 non-null  float64
#  21  mort_acc                    407319 non-null  float64
#  22  num_actv_bc_tl              407319 non-null  float64
#  23  num_actv_rev_tl             407319 non-null  float64
#  24  num_bc_tl                   407319 non-null  float64
#  25  num_il_tl                   407319 non-null  float64
#  26  num_tl_op_past_12m          407319 non-null  float64
#  27  pct_tl_nvr_dlq              407319 non-null  float64
#  28  total_il_high_credit_limit  407319 non-null  float64
#  29  debt_settlement_flag        407319 non-null  category
# dtypes: category(6), float64(24)
# memory usage: 80.0 MB

# %% [markdown]
# ### Authomatic report

# %% [markdown]
# Firstly, we are going to perform an authomatic EDA report, with the Sweetviz:

# %%
# We will use the minidatset with the 30 variables used in the RFECV

    # Analyzing the dataset
#advert_report = sv.analyze(dataset)

    # Display the report
#advert_report.show_html('01_EDA_report.html')

# %% [markdown]
# ### Correlations

# %% [markdown]
# A correlation coefficient is a numerical measure of some type of correlation, meaning a statistical relationship between two variables. The variables may be two columns of a given data set of observations, often called a sample, or two components of a multivariate random variable with a known distribution.
#
# Several types of correlation coefficient exist, each with their own definition and own range of usability and characteristics. They all assume values in the range from −1 to +1, where ±1 indicates the strongest possible agreement and 0 the strongest possible disagreement.

# %%
display(HTML(dataset.corr().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>funded_amnt</th>
#       <th>int_rate</th>
#       <th>annual_inc</th>
#       <th>inq_last_6mths</th>
#       <th>open_acc</th>
#       <th>revol_bal</th>
#       <th>revol_util</th>
#       <th>total_acc</th>
#       <th>acc_open_past_24mths</th>
#       <th>avg_cur_bal</th>
#       <th>bc_open_to_buy</th>
#       <th>bc_util</th>
#       <th>mo_sin_old_il_acct</th>
#       <th>mo_sin_old_rev_tl_op</th>
#       <th>mo_sin_rcnt_rev_tl_op</th>
#       <th>mo_sin_rcnt_tl</th>
#       <th>mort_acc</th>
#       <th>num_actv_bc_tl</th>
#       <th>num_actv_rev_tl</th>
#       <th>num_bc_tl</th>
#       <th>num_il_tl</th>
#       <th>num_tl_op_past_12m</th>
#       <th>pct_tl_nvr_dlq</th>
#       <th>total_il_high_credit_limit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>funded_amnt</th>
#       <td>1.000000</td>
#       <td>0.133590</td>
#       <td>0.329325</td>
#       <td>-0.022661</td>
#       <td>0.174385</td>
#       <td>0.329716</td>
#       <td>0.115093</td>
#       <td>0.198954</td>
#       <td>0.000933</td>
#       <td>0.237201</td>
#       <td>0.208753</td>
#       <td>0.050704</td>
#       <td>0.133876</td>
#       <td>0.171035</td>
#       <td>0.056327</td>
#       <td>0.035934</td>
#       <td>0.223964</td>
#       <td>0.196369</td>
#       <td>0.151639</td>
#       <td>0.190992</td>
#       <td>0.066591</td>
#       <td>-0.029136</td>
#       <td>0.092835</td>
#       <td>0.192083</td>
#     </tr>
#     <tr>
#       <th>int_rate</th>
#       <td>0.133590</td>
#       <td>1.000000</td>
#       <td>-0.087100</td>
#       <td>0.236723</td>
#       <td>-0.006551</td>
#       <td>-0.037833</td>
#       <td>0.220094</td>
#       <td>-0.047544</td>
#       <td>0.209257</td>
#       <td>-0.082288</td>
#       <td>-0.285257</td>
#       <td>0.243281</td>
#       <td>-0.090500</td>
#       <td>-0.131213</td>
#       <td>-0.123367</td>
#       <td>-0.147712</td>
#       <td>-0.064537</td>
#       <td>0.021275</td>
#       <td>0.097510</td>
#       <td>-0.083609</td>
#       <td>-0.006423</td>
#       <td>0.233349</td>
#       <td>-0.069748</td>
#       <td>-0.022712</td>
#     </tr>
#     <tr>
#       <th>annual_inc</th>
#       <td>0.329325</td>
#       <td>-0.087100</td>
#       <td>1.000000</td>
#       <td>0.032627</td>
#       <td>0.120819</td>
#       <td>0.289246</td>
#       <td>0.034450</td>
#       <td>0.167322</td>
#       <td>0.040371</td>
#       <td>0.321133</td>
#       <td>0.167706</td>
#       <td>-0.009130</td>
#       <td>0.119512</td>
#       <td>0.137861</td>
#       <td>0.040484</td>
#       <td>-0.013853</td>
#       <td>0.219119</td>
#       <td>0.100936</td>
#       <td>0.064352</td>
#       <td>0.127374</td>
#       <td>0.087119</td>
#       <td>0.044854</td>
#       <td>-0.009452</td>
#       <td>0.256792</td>
#     </tr>
#     <tr>
#       <th>inq_last_6mths</th>
#       <td>-0.022661</td>
#       <td>0.236723</td>
#       <td>0.032627</td>
#       <td>1.000000</td>
#       <td>0.135279</td>
#       <td>-0.023772</td>
#       <td>-0.090235</td>
#       <td>0.147500</td>
#       <td>0.253966</td>
#       <td>-0.032849</td>
#       <td>0.018532</td>
#       <td>-0.076969</td>
#       <td>0.011837</td>
#       <td>-0.009264</td>
#       <td>-0.180631</td>
#       <td>-0.221842</td>
#       <td>0.035303</td>
#       <td>0.055193</td>
#       <td>0.096347</td>
#       <td>0.120452</td>
#       <td>0.068445</td>
#       <td>0.299375</td>
#       <td>-0.022747</td>
#       <td>0.047114</td>
#     </tr>
#     <tr>
#       <th>open_acc</th>
#       <td>0.174385</td>
#       <td>-0.006551</td>
#       <td>0.120819</td>
#       <td>0.135279</td>
#       <td>1.000000</td>
#       <td>0.209923</td>
#       <td>-0.156566</td>
#       <td>0.689136</td>
#       <td>0.471063</td>
#       <td>-0.126037</td>
#       <td>0.288771</td>
#       <td>-0.110375</td>
#       <td>0.130329</td>
#       <td>0.129646</td>
#       <td>-0.226202</td>
#       <td>-0.208968</td>
#       <td>0.100512</td>
#       <td>0.524243</td>
#       <td>0.649323</td>
#       <td>0.485848</td>
#       <td>0.390702</td>
#       <td>0.344129</td>
#       <td>0.115742</td>
#       <td>0.353125</td>
#     </tr>
#     <tr>
#       <th>revol_bal</th>
#       <td>0.329716</td>
#       <td>-0.037833</td>
#       <td>0.289246</td>
#       <td>-0.023772</td>
#       <td>0.209923</td>
#       <td>1.000000</td>
#       <td>0.222940</td>
#       <td>0.173578</td>
#       <td>-0.025720</td>
#       <td>0.290407</td>
#       <td>0.194253</td>
#       <td>0.149815</td>
#       <td>0.096151</td>
#       <td>0.214792</td>
#       <td>0.037086</td>
#       <td>0.044226</td>
#       <td>0.188631</td>
#       <td>0.292189</td>
#       <td>0.286728</td>
#       <td>0.205176</td>
#       <td>0.000994</td>
#       <td>-0.034772</td>
#       <td>0.127521</td>
#       <td>0.105857</td>
#     </tr>
#     <tr>
#       <th>revol_util</th>
#       <td>0.115093</td>
#       <td>0.220094</td>
#       <td>0.034450</td>
#       <td>-0.090235</td>
#       <td>-0.156566</td>
#       <td>0.222940</td>
#       <td>1.000000</td>
#       <td>-0.125096</td>
#       <td>-0.220319</td>
#       <td>0.133182</td>
#       <td>-0.470256</td>
#       <td>0.837527</td>
#       <td>0.053880</td>
#       <td>-0.010955</td>
#       <td>0.180871</td>
#       <td>0.161537</td>
#       <td>0.012068</td>
#       <td>0.111998</td>
#       <td>0.103497</td>
#       <td>-0.152466</td>
#       <td>0.021287</td>
#       <td>-0.214050</td>
#       <td>-0.014950</td>
#       <td>0.037489</td>
#     </tr>
#     <tr>
#       <th>total_acc</th>
#       <td>0.198954</td>
#       <td>-0.047544</td>
#       <td>0.167322</td>
#       <td>0.147500</td>
#       <td>0.689136</td>
#       <td>0.173578</td>
#       <td>-0.125096</td>
#       <td>1.000000</td>
#       <td>0.421804</td>
#       <td>0.041706</td>
#       <td>0.219533</td>
#       <td>-0.098491</td>
#       <td>0.338804</td>
#       <td>0.282372</td>
#       <td>-0.164060</td>
#       <td>-0.188915</td>
#       <td>0.355581</td>
#       <td>0.270998</td>
#       <td>0.379473</td>
#       <td>0.625168</td>
#       <td>0.667113</td>
#       <td>0.314893</td>
#       <td>0.026399</td>
#       <td>0.402216</td>
#     </tr>
#     <tr>
#       <th>acc_open_past_24mths</th>
#       <td>0.000933</td>
#       <td>0.209257</td>
#       <td>0.040371</td>
#       <td>0.253966</td>
#       <td>0.471063</td>
#       <td>-0.025720</td>
#       <td>-0.220319</td>
#       <td>0.421804</td>
#       <td>1.000000</td>
#       <td>-0.100384</td>
#       <td>0.094586</td>
#       <td>-0.162232</td>
#       <td>-0.002062</td>
#       <td>-0.051587</td>
#       <td>-0.404603</td>
#       <td>-0.440492</td>
#       <td>0.049133</td>
#       <td>0.194178</td>
#       <td>0.317409</td>
#       <td>0.267868</td>
#       <td>0.252913</td>
#       <td>0.740949</td>
#       <td>0.071088</td>
#       <td>0.169635</td>
#     </tr>
#     <tr>
#       <th>avg_cur_bal</th>
#       <td>0.237201</td>
#       <td>-0.082288</td>
#       <td>0.321133</td>
#       <td>-0.032849</td>
#       <td>-0.126037</td>
#       <td>0.290407</td>
#       <td>0.133182</td>
#       <td>0.041706</td>
#       <td>-0.100384</td>
#       <td>1.000000</td>
#       <td>0.048985</td>
#       <td>0.067176</td>
#       <td>0.122967</td>
#       <td>0.129386</td>
#       <td>0.164766</td>
#       <td>0.050695</td>
#       <td>0.450611</td>
#       <td>-0.114279</td>
#       <td>-0.162280</td>
#       <td>-0.047987</td>
#       <td>0.028593</td>
#       <td>-0.073938</td>
#       <td>-0.040766</td>
#       <td>0.192494</td>
#     </tr>
#     <tr>
#       <th>bc_open_to_buy</th>
#       <td>0.208753</td>
#       <td>-0.285257</td>
#       <td>0.167706</td>
#       <td>0.018532</td>
#       <td>0.288771</td>
#       <td>0.194253</td>
#       <td>-0.470256</td>
#       <td>0.219533</td>
#       <td>0.094586</td>
#       <td>0.048985</td>
#       <td>1.000000</td>
#       <td>-0.545406</td>
#       <td>0.034247</td>
#       <td>0.192514</td>
#       <td>-0.058894</td>
#       <td>-0.044520</td>
#       <td>0.127616</td>
#       <td>0.253730</td>
#       <td>0.117376</td>
#       <td>0.403438</td>
#       <td>-0.025760</td>
#       <td>0.092208</td>
#       <td>0.156566</td>
#       <td>0.049753</td>
#     </tr>
#     <tr>
#       <th>bc_util</th>
#       <td>0.050704</td>
#       <td>0.243281</td>
#       <td>-0.009130</td>
#       <td>-0.076969</td>
#       <td>-0.110375</td>
#       <td>0.149815</td>
#       <td>0.837527</td>
#       <td>-0.098491</td>
#       <td>-0.162232

# %% [markdown]
# #### Heatmap

# %%
    # We create a mask in order to omit the superior part
mask = np.triu(np.ones_like(dataset.corr(), dtype = bool))
    
    # Figure size
f, ax = plt.subplots(figsize=(14, 14))

    # Plot with seaborn
sns.heatmap(dataset.corr(), annot = True, fmt = '.1f', mask = mask, square = True, linewidths = .5, cmap = "rocket_r");

# %% [markdown]
# The following variables are highly correlated:
#
# - `bc_util` & `revol_util`: Both rates are highly correlated.
#
# - `num_actv_rev_tl` & `num_actv_bc_tl`: We deduce that most of the revolving trades have a bank card account associated.
#
# - `total_acc` &  `open_acc`: This is hihgly correlated because one is included in the other.
#
# - `mo_sin_rcnt_tl` & `mo_sin_rcnt_rev_tl_op`: If we analyze the graph we can conclude that the most recent account were revolute accounts, because they are hihgly correlated. The months since the last open are practically the same.
#
# - `num_actv_rev_tl` & `open_acc`: According to the plot we could deduce that a great percentage of the open accounts are active revolving accounts.
#
# - `num_il_tl` & `total_acc`: We have another type account called installment account, this is correlated with total accounts because is an account.
#
# - `num_tl_op_past_12m` & `acc_open_past_24mths`: The total amount of accounts opened in the past 12 months is included in the accounts opened in the last 24 months.
#
# - `total_il_high_credit_limit` & `num_il_tl`: The more installment accounts, the more high credit limit.

# %% [markdown]
# #### Pairplot

# %%
    # Select those columns which are high correlated
columns = ['loan_status', 'num_actv_rev_tl', 'num_actv_bc_tl', 'total_acc', 'open_acc', 'mo_sin_rcnt_tl', 'bc_util', 
           'revol_util', 'mo_sin_rcnt_rev_tl_op', 'num_il_tl', 'num_tl_op_past_12m', 'acc_open_past_24mths', 
           'total_il_high_credit_limit']

    # In order to avoid errors, we will take a sample
df_viz = dataset[columns].sample(n = 1000, replace = True, random_state = 1322)

    # For this function we will use pairplot()
sns.pairplot(df_viz, hue = 'loan_status', palette = "rocket_r");

# %% [markdown]
# We made a pairplot in order to visualize those correlations and we can conclude that is not as clear as we thought initially, so we are not going to drop any of them.

# %% [markdown]
# ### Outliers

# %% [markdown]
# #### Boxplots

# %% [markdown]
# In descriptive statistics, a box plot or boxplot is a method for graphically depicting groups of numerical data through their quartiles. Box plots may also have lines extending from the boxes (whiskers) indicating variability outside the upper and lower quartiles, hence the terms box-and-whisker plot and box-and-whisker diagram. Outliers may be plotted as individual points.

# %%
    # Plot with seaborn
sns.boxplot(data = dataset, x = 'term', y = 'funded_amnt', palette = 'rocket_r');

# %% [markdown]
# In the plot above, we can see that we have some outliers when term = 0 (36 months), later we will study them...

# %%
    # Plot with seaborn
sns.boxplot(data = dataset, x = 'home_ownership', y = 'funded_amnt', palette = 'rocket_r');

# %% [markdown]
# In this case, we have some outliers in the forth type. Also we can see that the funded amount is higher when you are in the second one.

# %%
    # Figure size
f, ax = plt.subplots(figsize=(11, 4))

    # Plot with seaborn
sns.boxplot(data = dataset, x = 'addr_state', y = 'funded_amnt', palette = 'rocket_r');

# %% [markdown]
# We can see that we have some states with outliers. Apart from that, there are some states with very high amounts, as the 0.

# %%
    # Plot with seaborn
sns.boxplot(data = dataset, x = 'debt_settlement_flag', y = 'funded_amnt', palette = 'rocket_r');

# %% [markdown]
# Here we have no outliers.

# %%
    # Plot with seaborn
sns.boxplot(data = dataset, x = 'emp_length', y = 'funded_amnt', palette = 'rocket_r');

# %% [markdown]
# We have some outliers in this variables, and is interesante that does not deppends on how many years have you been working, the mean funded amount is between 10000 and 15000.

# %% [markdown]
# #### Outlier detection and dropping

# %% [markdown]
# After researching some outlier detection methods, we conclude that we will perform the **Interquartile range (IQR)**:
#
# *The interquartile range (IQR), also called the midspread or middle 50%, or technically H-spread, is a measure of statistical dispersion, being equal to the difference between 75th and 25th percentiles, or between upper and lower quartiles, IQR = Q3 − Q1.*
# *In other words, the IQR is the first quartile subtracted from the third quartile; these quartiles can be clearly seen on a box plot on the data.*
# *It is a measure of the dispersion similar to standard deviation or variance, but is much more robust against outliers.*

# %%
    # First we will calculate IQR
Q1 = dataset.quantile(0.25)
Q3 = dataset.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# funded_amnt                   1.410595
# int_rate                      1.356606
# annual_inc                    0.661720
# inq_last_6mths                1.054718
# open_acc                      1.285441
# revol_bal                     0.643604
# revol_util                    1.506697
# total_acc                     1.241385
# acc_open_past_24mths          0.953050
# avg_cur_bal                   0.977156
# bc_open_to_buy                0.700739
# bc_util                       1.625654
# mo_sin_old_il_acct            1.029189
# mo_sin_old_rev_tl_op          1.196159
# mo_sin_rcnt_rev_tl_op         0.706781
# mo_sin_rcnt_tl                0.748297
# mort_acc                      1.437299
# num_actv_bc_tl                1.398246
# num_actv_rev_tl               1.269640
# num_bc_tl                     1.237418
# num_il_tl                     1.069632
# num_tl_op_past_12m            1.111426
# pct_tl_nvr_dlq                1.015820
# total_il_high_credit_limit    0.955867
# dtype: float64

# %% [markdown]
# As we now have the IQR scores, it’s time to get hold on outliers. The below code will give an output with some true and false values. The data point where we have False that means these values are valid whereas True indicates presence of an outlier.

# %%
    # First we select only numerical variables
dataset.select_dtypes(include = ['float64', 'int64']).columns
# Out:
# Index(['funded_amnt', 'int_rate', 'annual_inc', 'inq_last_6mths', 'open_acc',
#        'revol_bal', 'revol_util', 'total_acc', 'acc_open_past_24mths',
#        'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
#        'mort_acc', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_tl',
#        'num_il_tl', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'total_il_high_credit_limit'],
#       dtype='object')

# %%
    # We create a copy
dataset_without_na = dataset.copy()

    # We select the numerical columns
columns = ['funded_amnt', 'int_rate', 'annual_inc', 'inq_last_6mths', 'open_acc', 'revol_bal', 'revol_util', 'total_acc', 
           'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 
           'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_tl',
           'num_il_tl', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'total_il_high_credit_limit']

    # Set to NaN those which are outliers
dataset_without_na[columns] = dataset_without_na[columns][~((dataset_without_na[columns] < (Q1 - 1.5 * IQR)) |(dataset_without_na[columns] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
    # Drop NaN
dataset_without_na = dataset_without_na.dropna()

    # Check the results...
dataset_without_na.shape
# Out:
# (192742, 30)

# %%
    # Dataset shape with outliers
dataset.shape
# Out:
# (407319, 30)

# %% [markdown]
# We have lots of outliers, but we do not know if there are influyent, in next notebooks we will study how to detect infuyent outliers and what do with them.

# %%
    # Save dataset
data = dataset
data.to_csv('data_preprocessed.csv', header = True, index = False)
