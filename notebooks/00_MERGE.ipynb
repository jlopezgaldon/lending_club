# %% [markdown]
# ### Title:
# # Data merge

# %% [markdown]
# ### Description:
# We are going to merge the 4 training datasets.

# %% [markdown]
# ### Authors:
# #### Hugo Cesar Octavio del Sueldo
# #### Jose Lopez Galdon

# %% [markdown]
# ### Date:
# 23/10/2020

# %% [markdown]
# ### Version:
# 1.0

# %% [markdown]
# ***

# %% [markdown]
# ### Libraries

# %% [markdown]
# We are going to start this EDA loading the respective libraries

# %%
    # Numpy & Pandas to work with the DF
import numpy as np
import pandas as pd

# %% [markdown]
# Secondly, we will load all the datasets:

# %% [markdown]
# ### Loan_training_set_1_4

# %%
    # To automate the work as much as possible, we will parameterize the codes, so in this case, we will create an objetct with
    # the path root
name = 'Loan_training_set_1_4'

data1 = pd.read_csv(f'../data/01_raw/{name}.csv', # Path root: here we include an f-string with the variable name to parametrize
                   skiprows = 1,                  # We skip the first rows
                   skipfooter = 2,                # We skip the last two rows
                   engine = 'python')             # To avoid warnings we use the python engine

# %% [markdown]
# Lets check our first dataset:

# %%
    # First 10 rows
data = data1
data.head(10)
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  112435993        NaN       2300         2300             2300   36 months
# 1  112290210        NaN      16000        16000            16000   60 months
# 2  112436985        NaN       6025         6025             6025   36 months
# 3  112439006        NaN      20400        20400            20400   36 months
# 4  112438929        NaN      13000        13000            13000   36 months
# 5  112230200        NaN      12000        12000            12000   36 months
# 6  112210041        NaN       6000         6000             6000   36 months
# 7  112360031        NaN      12000        12000            12000   60 months
# 8  112038251        NaN      11575        11575            11575   36 months
# 9  112134207        NaN      20400        20400            20400   60 months
#
#   int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# ...

# %%
    # Last 10 rows
data = data1
data.tail(10)
# Out:
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 105441  102156471        NaN      29400        29400            29400
# 105442  102335454        NaN      35000        35000            35000
# 105443  102395624        NaN      35000        35000            35000
# 105444  102426796        NaN      12000        12000            12000
# 105445  102385348        NaN      19200        19200            19200
# 105446  102556443        NaN      24000        24000            24000
# 105447  102653304        NaN      10000        10000            10000
# 105448  102628603        NaN      10050        10050            10050
# 105449  102196576        NaN       6000         6000             6000
# 105450   99799684        NaN      30000        30000            30000
#
#               term int_rate  installment grade sub_grade  ...  \
# 105441   60 months   13.99%       683.94     C        C3  ...
# 105442   60 months   25.49%      1037.38     E        E4  ...
# ...

# %% [markdown]
# ***

# %% [markdown]
# ### Loan_training_set_2_4

# %%
    # To automate the work as much as possible, we will parameterize the codes, so in this case, we will create an objetct with
    # the path root
name = 'Loan_training_set_2_4'

data2 = pd.read_csv(f'../data/01_raw/{name}.csv', # Path root: here we include an f-string with the variable name to parametrize
                   skiprows = 1,                  # We skip the first rows
                   skipfooter = 2,                # We skip the last two rows
                   engine = 'python')             # To avoid warnings we use the python engine

# %% [markdown]
# Lets check our second dataset:

# %%
    # First 10 rows
data = data2
data.head(10)
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  118659541        NaN      33000        33000            33000   36 months
# 1  119321612        NaN      40000        40000            40000   60 months
# 2  120122535        NaN      12000        12000            12000   36 months
# 3  119246018        NaN       7000         7000             7000   36 months
# 4  119374887        NaN      32000        32000            32000   36 months
# 5  120122034        NaN      16000        16000            16000   36 months
# 6  120119855        NaN       4000         4000             4000   36 months
# 7  120117008        NaN      20000        20000            20000   60 months
# 8  119979388        NaN       1200         1200             1200   36 months
# 9  120117838        NaN      24000        24000            24000   60 months
#
#   int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# ...

# %%
    # Last 10 rows
data = data2
data.tail(10)
# Out:
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 122691  110704789        NaN       7000         7000             7000
# 122692  110969859        NaN      18000        18000            18000
# 122693  111077394        NaN      17000        17000            17000
# 122694  111068978        NaN      30000        30000            30000
# 122695  110790891        NaN      14400        14400            14400
# 122696  110380307        NaN       6000         6000             6000
# 122697  110479222        NaN      20000        20000            20000
# 122698  109866673        NaN      35000        35000            35000
# 122699  110394553        NaN      30775        30775            30525
# 122700  109517381        NaN      18900        18900            18900
#
#               term int_rate  installment grade sub_grade  ...  \
# 122691   36 months   24.85%       277.77     E        E3  ...
# 122692   60 months   14.08%       419.58     C        C3  ...
# ...

# %% [markdown]
# ***

# %% [markdown]
# ### Loan_training_set_3_4

# %%
    # To automate the work as much as possible, we will parameterize the codes, so in this case, we will create an objetct with
    # the path root
name = 'Loan_training_set_3_4'

data3 = pd.read_csv(f'../data/01_raw/{name}.csv', # Path root: here we include an f-string with the variable name to parametrize
                   skiprows = 1,                  # We skip the first rows
                   skipfooter = 2,                # We skip the last two rows
                   engine = 'python')             # To avoid warnings we use the python engine

# %% [markdown]
# Lets check our second dataset:

# %%
    # First 10 rows
data = data3
data.head(10)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  38098114        NaN      15000        15000            15000   60 months
# 1  36805548        NaN      10400        10400            10400   36 months
# 2  37842129        NaN      21425        21425            21425   60 months
# 3  37612354        NaN      12800        12800            12800   60 months
# 4  37662224        NaN       7650         7650             7650   36 months
# 5  37822187        NaN       9600         9600             9600   36 months
# 6  37741884        NaN       2500         2500             2500   36 months
# 7  37854444        NaN      16000        16000            16000   60 months
# 8  36804663        NaN      23325        23325            23325   36 months
# 9  37642222        NaN       5250         5250             5250   36 months
#
#   int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# ...

# %%
    # Last 10 rows
data = data3
data.tail(10)
# Out:
#              id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 235619  9715141        NaN       6000         6000             6000
# 235620  9695736        NaN       8525         8525             8525
# 235621  9007579        NaN      18000        18000            17975
# 235622  9745484        NaN      15000        15000            15000
# 235623  9745590        NaN      10000        10000            10000
# 235624  8598660        NaN      18400        18400            18400
# 235625  9684700        NaN      22000        22000            22000
# 235626  9604874        NaN       2000         2000             2000
# 235627  9584776        NaN      20700        20700            20700
# 235628  9199665        NaN      10000        10000             9975
#
#               term int_rate  installment grade sub_grade  ...  \
# 235619   36 months   15.61%       209.79     C        C4  ...
# 235620   60 months   18.25%       217.65     D        D3  ...
# ...

# %% [markdown]
# ***

# %% [markdown]
# ### Loan_training_set_4_4

# %%
    # To automate the work as much as possible, we will parameterize the codes, so in this case, we will create an objetct with
    # the path root
name = 'Loan_training_set_4_4'

data4 = pd.read_csv(f'../data/01_raw/{name}.csv', # Path root: here we include an f-string with the variable name to parametrize
                   skiprows = 1,                  # We skip the first rows
                   skipfooter = 2,                # We skip the last two rows
                   engine = 'python')             # To avoid warnings we use the python engine

# %% [markdown]
# Lets check our second dataset:

# %%
    # First 10 rows
data = data4
data.head(10)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68506789        NaN      12000        12000          12000.0   60 months
# 1  68426545        NaN      16000        16000          16000.0   60 months
# 2  68394562        NaN      30000        30000          30000.0   36 months
# 3  66583801        NaN      33600        33600          33600.0   36 months
# 4  68466916        NaN      25000        25000          25000.0   36 months
# 5  68506862        NaN      20000        20000          20000.0   60 months
# 6  68416916        NaN      28000        28000          28000.0   60 months
# 7  68446784        NaN      12000        12000          12000.0   36 months
# 8  68446093        NaN      11550        11550          11550.0   60 months
# 9  68387134        NaN       2500         2500           2500.0   36 months
#
#   int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# ...

# %%
    # Last 10 rows
data = data4
data.tail(10)
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 421085  36421485        NaN       4000         4000           4000.0
# 421086  35094480        NaN       7500         7500           7500.0
# 421087  36260758        NaN      10850        10850          10850.0
# 421088  36221446        NaN      11575        11575          11575.0
# 421089  36330911        NaN      12000        12000          12000.0
# 421090  36371250        NaN      10000        10000          10000.0
# 421091  36441262        NaN      24000        24000          24000.0
# 421092  36271333        NaN      13000        13000          13000.0
# 421093  36490806        NaN      12000        12000          12000.0
# 421094  36271262        NaN      20000        20000          20000.0
#
#               term int_rate  installment grade sub_grade  ...  \
# 421085   36 months    8.67%       126.59     B        B1  ...
# 421086   36 months    9.49%       240.22     B        B2  ...
# ...

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# ### Concat

# %% [markdown]
# Finally, we will concat our dataframes.

# %%
data_concat = pd.concat([data1, data2, data3, data4])

# %% [markdown]
# Lets have a look to our new dataset

# %%
data_concat
# Out:
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0       112435993        NaN       2300         2300           2300.0
# 1       112290210        NaN      16000        16000          16000.0
# 2       112436985        NaN       6025         6025           6025.0
# 3       112439006        NaN      20400        20400          20400.0
# 4       112438929        NaN      13000        13000          13000.0
# ...           ...        ...        ...          ...              ...
# 421090   36371250        NaN      10000        10000          10000.0
# 421091   36441262        NaN      24000        24000          24000.0
# 421092   36271333        NaN      13000        13000          13000.0
# 421093   36490806        NaN      12000        12000          12000.0
# 421094   36271262        NaN      20000        20000          20000.0
#
#               term int_rate  installment grade sub_grade  ...  \
# 0        36 months   12.62%        77.08     C        C1  ...
# ...

# %% [markdown]
# Once we have our data loaded, we will continue with the information of the columns...

# %%
data = data_concat
data.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 884876 entries, 0 to 421094
# Data columns (total 151 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   id                                          884876 non-null  int64
#  1   member_id                                   0 non-null       float64
#  2   loan_amnt                                   884876 non-null  int64
#  3   funded_amnt                                 884876 non-null  int64
#  4   funded_amnt_inv                             884876 non-null  float64
#  5   term                                        884876 non-null  object
#  6   int_rate                                    884876 non-null  object
#  7   installment                                 884876 non-null  float64
#  8   grade                                       884876 non-null  object
# ...

# %%
    # Saving the data
# data.to_csv('data_train_merge.csv', header = True, index = False)

# %% [markdown]
# ***

# %% [markdown]
# ***
